# %%
import pandas as pd
import numpy as np
from csdi import CSDI_base
import matplotlib.pyplot as plt
from utils import *
from calc_metrics import *
from training import train, evaluate, impute
from preprocessing import SegmentStandardScaler, get_data_MCAR, get_data_missing_intervals
import datetime
import torch
import warnings 
warnings.filterwarnings('ignore')
import random
np.random.seed(123)

torch.backends.cuda.enable_mem_efficient_sdp(False)
torch.backends.cuda.enable_flash_sdp(False)
torch.backends.cuda.enable_math_sdp(True)

# %%
torch.cuda.empty_cache()
dev = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# =========================================
# Define params

share_misses = 0.1 # share of misses
length_of_seq = 100 # length of dataframe slice used for training
sigma_GP = 0.02 # variance parameter of DSPD model
use_DSPD = True # flag for using DSPS (if False, original CSDI is being trained)
df_name = 'Exchange' # name of the dataframe

# =========================================

# %% [markdown]
# ## Preprocessing

# %%
# load the data
df_train_nm = get_data_MCAR('ETTM')
df = get_data_MCAR('ETTM', create_misses = True, share_of_misses = share_misses)

# save indexes of missing values
missing_values = df[df.target.isna()].index.values

# scale the data
sc_train = SegmentStandardScaler(segments=df.segment.unique())
df_train = sc_train.fit_transform(df.copy())
df_train_only_missed = df_train_nm.sort_values(['timestamp', 'segment'])[df_train_nm.index.isin(missing_values)]
df_train_only_not_missed = df_train_nm.sort_values(['timestamp', 'segment'])[~df_train_nm.index.isin(missing_values)]

# %%
# create datasets - one for the training and one for the imputation
cust_df_train = Custom_Dataset(df_train, length_of_sequence=length_of_seq)
cust_df_test = Custom_Dataset(df_train, length_of_sequence=length_of_seq, use_rolling_window = False)

# %%
# create custom dataloader
df_train_load = DataLoader(cust_df_train, batch_size=32, shuffle=1)

# %% [markdown]
# ## Training

# %%
# initialize the imputer
CSDI = CSDI_base(target_dim = df_train_nm.segment.nunique(),
                 emb_feature_dim = 16, 
                 emb_time_dim = 128, 
                 diffusion=128, 
                 diffusion_embedding_dim=128, 
                 device = dev, 
                 num_steps= 50, 
                 gp_noise=use_DSPD, 
                 gp_sigma=sigma_GP
                )
CSDI.to(dev)
# Out:
# CSDI_base(
#   (gp): GaussianProcess()
#   (embed_layer): Embedding(7, 16)
#   (diffmodel): diff_CSDI(
#     (diffusion_embedding): DiffusionEmbedding(
#       (projection1): Linear(in_features=8, out_features=8, bias=True)
#       (projection2): Linear(in_features=8, out_features=8, bias=True)
#     )
#     (input_projection): Conv1d(2, 64, kernel_size=(1,), stride=(1,))
#     (output_projection1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#     (output_projection2): Conv1d(64, 1, kernel_size=(1,), stride=(1,))
#     (residual_layers): ModuleList(
#       (0-3): 4 x ResidualBlock(
#         (diffusion_projection): Linear(in_features=8, out_features=64, bias=True)
#         (cond_projection): Conv1d(145, 128, kernel_size=(1,), stride=(1,))
#         (mid_projection): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#         (output_projection): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#         (time_layer): TransformerEncoder(
#           (layers): ModuleList(
#             (0): TransformerEncoderLayer(
#               (self_attn): MultiheadAttention(
#                 (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#               )
#               (linear1): Linear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (linear2): Linear(in_features=64, out_features=64, bias=True)
#               (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#               (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (dropout2): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (feature_layer): TransformerEncoder(
#           (layers): ModuleList(
#             (0): TransformerEncoderLayer(
#               (self_attn): MultiheadAttention(
#                 (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#               )
#               (linear1): Linear(in_features=64, out_features=64, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (linear2): Linear(in_features=64, out_features=64, bias=True)
#               (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#               (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#               (dropout1): Dropout(p=0.1, inplace=False)
#               (dropout2): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#   )
# )

# %%
# train the imputer
train(CSDI,
      df_train_load,
      epochs= 200,
      learning_rate= 1e-3
      )
# Out:
# 100%|██████████| 13/13 [00:10<00:00,  1.29it/s, avg_epoch_loss=0.772, epoch=0]
# 100%|██████████| 13/13 [00:01<00:00, 10.34it/s, avg_epoch_loss=0.398, epoch=1]
# 100%|██████████| 13/13 [00:01<00:00, 10.82it/s, avg_epoch_loss=0.354, epoch=2]
# 100%|██████████| 13/13 [00:01<00:00, 11.02it/s, avg_epoch_loss=0.336, epoch=3]
# 100%|██████████| 13/13 [00:01<00:00, 10.95it/s, avg_epoch_loss=0.35, epoch=4]
# 100%|██████████| 13/13 [00:01<00:00, 10.88it/s, avg_epoch_loss=0.315, epoch=5]
# 100%|██████████| 13/13 [00:01<00:00, 11.18it/s, avg_epoch_loss=0.35, epoch=6]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.293, epoch=7]
# 100%|██████████| 13/13 [00:01<00:00, 11.22it/s, avg_epoch_loss=0.273, epoch=8]
# 100%|██████████| 13/13 [00:01<00:00, 11.20it/s, avg_epoch_loss=0.256, epoch=9]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.271, epoch=10]
# 100%|██████████| 13/13 [00:01<00:00, 11.06it/s, avg_epoch_loss=0.242, epoch=11]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.203, epoch=12]
# 100%|██████████| 13/13 [00:01<00:00, 11.19it/s, avg_epoch_loss=0.201, epoch=13]
# 100%|██████████| 13/13 [00:01<00:00, 11.06it/s, avg_epoch_loss=0.216, epoch=14]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.21, epoch=15]
# 100%|██████████| 13/13 [00:01<00:00, 11.11it/s, avg_epoch_loss=0.191, epoch=16]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.199, epoch=17]
# 100%|██████████| 13/13 [00:01<00:00, 11.18it/s, avg_epoch_loss=0.174, epoch=18]
# 100%|██████████| 13/13 [00:01<00:00, 11.22it/s, avg_epoch_loss=0.185, epoch=19]
# 100%|██████████| 13/13 [00:01<00:00, 11.12it/s, avg_epoch_loss=0.165, epoch=20]
# 100%|██████████| 13/13 [00:01<00:00, 11.23it/s, avg_epoch_loss=0.175, epoch=21]
# 100%|██████████| 13/13 [00:01<00:00, 11.11it/s, avg_epoch_loss=0.17, epoch=22]
# 100%|██████████| 13/13 [00:01<00:00, 10.96it/s, avg_epoch_loss=0.151, epoch=23]
# 100%|██████████| 13/13 [00:01<00:00, 11.00it/s, avg_epoch_loss=0.147, epoch=24]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.155, epoch=25]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.158, epoch=26]
# 100%|██████████| 13/13 [00:01<00:00, 11.11it/s, avg_epoch_loss=0.151, epoch=27]
# 100%|██████████| 13/13 [00:01<00:00, 11.16it/s, avg_epoch_loss=0.154, epoch=28]
# 100%|██████████| 13/13 [00:01<00:00, 11.11it/s, avg_epoch_loss=0.148, epoch=29]
# 100%|██████████| 13/13 [00:01<00:00, 11.12it/s, avg_epoch_loss=0.153, epoch=30]
# 100%|██████████| 13/13 [00:01<00:00, 11.04it/s, avg_epoch_loss=0.132, epoch=31]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.136, epoch=32]
# 100%|██████████| 13/13 [00:01<00:00, 11.12it/s, avg_epoch_loss=0.136, epoch=33]
# 100%|██████████| 13/13 [00:01<00:00, 11.12it/s, avg_epoch_loss=0.129, epoch=34]
# 100%|██████████| 13/13 [00:01<00:00, 11.04it/s, avg_epoch_loss=0.138, epoch=35]
# 100%|██████████| 13/13 [00:01<00:00, 10.95it/s, avg_epoch_loss=0.173, epoch=36]
# 100%|██████████| 13/13 [00:01<00:00, 10.91it/s, avg_epoch_loss=0.153, epoch=37]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.144, epoch=38]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.148, epoch=39]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.142, epoch=40]
# 100%|██████████| 13/13 [00:01<00:00, 11.03it/s, avg_epoch_loss=0.138, epoch=41]
# 100%|██████████| 13/13 [00:01<00:00, 11.06it/s, avg_epoch_loss=0.126, epoch=42]
# 100%|██████████| 13/13 [00:01<00:00, 11.04it/s, avg_epoch_loss=0.132, epoch=43]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.167, epoch=44]
# 100%|██████████| 13/13 [00:01<00:00, 10.98it/s, avg_epoch_loss=0.129, epoch=45]
# 100%|██████████| 13/13 [00:01<00:00, 11.10it/s, avg_epoch_loss=0.115, epoch=46]
# 100%|██████████| 13/13 [00:01<00:00, 11.08it/s, avg_epoch_loss=0.136, epoch=47]
# 100%|██████████| 13/13 [00:01<00:00, 11.08it/s, avg_epoch_loss=0.108, epoch=48]
# 100%|██████████| 13/13 [00:01<00:00, 10.85it/s, avg_epoch_loss=0.112, epoch=49]
# 100%|██████████| 13/13 [00:01<00:00, 11.00it/s, avg_epoch_loss=0.127, epoch=50]
# 100%|██████████| 13/13 [00:01<00:00, 10.93it/s, avg_epoch_loss=0.119, epoch=51]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0957, epoch=52]
# 100%|██████████| 13/13 [00:01<00:00, 10.47it/s, avg_epoch_loss=0.118, epoch=53]
# 100%|██████████| 13/13 [00:01<00:00, 11.04it/s, avg_epoch_loss=0.133, epoch=54]
# 100%|██████████| 13/13 [00:01<00:00, 10.96it/s, avg_epoch_loss=0.129, epoch=55]
# 100%|██████████| 13/13 [00:01<00:00, 10.95it/s, avg_epoch_loss=0.117, epoch=56]
# 100%|██████████| 13/13 [00:01<00:00, 10.93it/s, avg_epoch_loss=0.121, epoch=57]
# 100%|██████████| 13/13 [00:01<00:00, 10.83it/s, avg_epoch_loss=0.103, epoch=58]
# 100%|██████████| 13/13 [00:01<00:00, 10.91it/s, avg_epoch_loss=0.0749, epoch=59]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.121, epoch=60]
# 100%|██████████| 13/13 [00:01<00:00, 11.02it/s, avg_epoch_loss=0.103, epoch=61]
# 100%|██████████| 13/13 [00:01<00:00, 11.06it/s, avg_epoch_loss=0.121, epoch=62]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.101, epoch=63]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.108, epoch=64]
# 100%|██████████| 13/13 [00:01<00:00, 10.82it/s, avg_epoch_loss=0.0813, epoch=65]
# 100%|██████████| 13/13 [00:01<00:00, 11.04it/s, avg_epoch_loss=0.103, epoch=66]
# 100%|██████████| 13/13 [00:01<00:00, 11.06it/s, avg_epoch_loss=0.113, epoch=67]
# 100%|██████████| 13/13 [00:01<00:00, 11.19it/s, avg_epoch_loss=0.108, epoch=68]
# 100%|██████████| 13/13 [00:01<00:00, 10.93it/s, avg_epoch_loss=0.107, epoch=69]
# 100%|██████████| 13/13 [00:01<00:00, 10.69it/s, avg_epoch_loss=0.0989, epoch=70]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.124, epoch=71]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.108, epoch=72]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.086, epoch=73]
# 100%|██████████| 13/13 [00:01<00:00, 10.98it/s, avg_epoch_loss=0.104, epoch=74]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.0977, epoch=75]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.102, epoch=76]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.0916, epoch=77]
# 100%|██████████| 13/13 [00:01<00:00, 11.23it/s, avg_epoch_loss=0.106, epoch=78]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.088, epoch=79]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.11, epoch=80]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.117, epoch=81]
# 100%|██████████| 13/13 [00:01<00:00, 11.08it/s, avg_epoch_loss=0.0854, epoch=82]
# 100%|██████████| 13/13 [00:01<00:00, 11.05it/s, avg_epoch_loss=0.0676, epoch=83]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.0747, epoch=84]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.0863, epoch=85]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.0826, epoch=86]
# 100%|██████████| 13/13 [00:01<00:00, 11.03it/s, avg_epoch_loss=0.0869, epoch=87]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.0646, epoch=88]
# 100%|██████████| 13/13 [00:01<00:00, 11.22it/s, avg_epoch_loss=0.0668, epoch=89]
# 100%|██████████| 13/13 [00:01<00:00, 11.07it/s, avg_epoch_loss=0.106, epoch=90]
# 100%|██████████| 13/13 [00:01<00:00, 11.16it/s, avg_epoch_loss=0.0733, epoch=91]
# 100%|██████████| 13/13 [00:01<00:00, 11.12it/s, avg_epoch_loss=0.101, epoch=92]
# 100%|██████████| 13/13 [00:01<00:00, 11.04it/s, avg_epoch_loss=0.0806, epoch=93]
# 100%|██████████| 13/13 [00:01<00:00, 10.80it/s, avg_epoch_loss=0.0999, epoch=94]
# 100%|██████████| 13/13 [00:01<00:00, 10.62it/s, avg_epoch_loss=0.089, epoch=95]
# 100%|██████████| 13/13 [00:01<00:00, 10.86it/s, avg_epoch_loss=0.0731, epoch=96]
# 100%|██████████| 13/13 [00:01<00:00, 10.71it/s, avg_epoch_loss=0.111, epoch=97]
# 100%|██████████| 13/13 [00:01<00:00, 10.63it/s, avg_epoch_loss=0.0944, epoch=98]
# 100%|██████████| 13/13 [00:01<00:00, 10.84it/s, avg_epoch_loss=0.0962, epoch=99]
# 100%|██████████| 13/13 [00:01<00:00, 10.83it/s, avg_epoch_loss=0.0852, epoch=100]
# 100%|██████████| 13/13 [00:01<00:00, 10.88it/s, avg_epoch_loss=0.0952, epoch=101]
# 100%|██████████| 13/13 [00:01<00:00, 10.93it/s, avg_epoch_loss=0.0784, epoch=102]
# 100%|██████████| 13/13 [00:01<00:00, 10.98it/s, avg_epoch_loss=0.0687, epoch=103]
# 100%|██████████| 13/13 [00:01<00:00, 10.87it/s, avg_epoch_loss=0.0771, epoch=104]
# 100%|██████████| 13/13 [00:01<00:00, 10.98it/s, avg_epoch_loss=0.0797, epoch=105]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.0628, epoch=106]
# 100%|██████████| 13/13 [00:01<00:00, 11.05it/s, avg_epoch_loss=0.0485, epoch=107]
# 100%|██████████| 13/13 [00:01<00:00, 10.91it/s, avg_epoch_loss=0.0749, epoch=108]
# 100%|██████████| 13/13 [00:01<00:00, 10.82it/s, avg_epoch_loss=0.0802, epoch=109]
# 100%|██████████| 13/13 [00:01<00:00, 10.73it/s, avg_epoch_loss=0.0948, epoch=110]
# 100%|██████████| 13/13 [00:01<00:00, 10.98it/s, avg_epoch_loss=0.0749, epoch=111]
# 100%|██████████| 13/13 [00:01<00:00, 10.96it/s, avg_epoch_loss=0.056, epoch=112]
# 100%|██████████| 13/13 [00:01<00:00, 11.11it/s, avg_epoch_loss=0.0808, epoch=113]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.0616, epoch=114]
# 100%|██████████| 13/13 [00:01<00:00, 11.04it/s, avg_epoch_loss=0.0787, epoch=115]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.102, epoch=116]
# 100%|██████████| 13/13 [00:01<00:00, 11.02it/s, avg_epoch_loss=0.0906, epoch=117]
# 100%|██████████| 13/13 [00:01<00:00, 11.06it/s, avg_epoch_loss=0.08, epoch=118]
# 100%|██████████| 13/13 [00:01<00:00, 11.06it/s, avg_epoch_loss=0.073, epoch=119]
# 100%|██████████| 13/13 [00:01<00:00, 10.79it/s, avg_epoch_loss=0.0577, epoch=120]
# 100%|██████████| 13/13 [00:01<00:00, 10.97it/s, avg_epoch_loss=0.0548, epoch=121]
# 100%|██████████| 13/13 [00:01<00:00, 11.01it/s, avg_epoch_loss=0.0661, epoch=122]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0816, epoch=123]
# 100%|██████████| 13/13 [00:01<00:00, 11.10it/s, avg_epoch_loss=0.0624, epoch=124]
# 100%|██████████| 13/13 [00:01<00:00, 11.12it/s, avg_epoch_loss=0.0586, epoch=125]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.0556, epoch=126]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.0599, epoch=127]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.075, epoch=128]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.0619, epoch=129]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.0621, epoch=130]
# 100%|██████████| 13/13 [00:01<00:00, 11.05it/s, avg_epoch_loss=0.0696, epoch=131]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.0578, epoch=132]
# 100%|██████████| 13/13 [00:01<00:00, 11.08it/s, avg_epoch_loss=0.0739, epoch=133]
# 100%|██████████| 13/13 [00:01<00:00, 11.12it/s, avg_epoch_loss=0.0884, epoch=134]
# 100%|██████████| 13/13 [00:01<00:00, 11.16it/s, avg_epoch_loss=0.0678, epoch=135]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.071, epoch=136]
# 100%|██████████| 13/13 [00:01<00:00, 11.06it/s, avg_epoch_loss=0.0601, epoch=137]
# 100%|██████████| 13/13 [00:01<00:00, 11.13it/s, avg_epoch_loss=0.0604, epoch=138]
# 100%|██████████| 13/13 [00:01<00:00, 11.12it/s, avg_epoch_loss=0.0599, epoch=139]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.0658, epoch=140]
# 100%|██████████| 13/13 [00:01<00:00, 11.22it/s, avg_epoch_loss=0.0749, epoch=141]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.0694, epoch=142]
# 100%|██████████| 13/13 [00:01<00:00, 10.92it/s, avg_epoch_loss=0.077, epoch=143]
# 100%|██████████| 13/13 [00:01<00:00, 10.85it/s, avg_epoch_loss=0.0753, epoch=144]
# 100%|██████████| 13/13 [00:01<00:00, 11.01it/s, avg_epoch_loss=0.0657, epoch=145]
# 100%|██████████| 13/13 [00:01<00:00, 11.09it/s, avg_epoch_loss=0.0752, epoch=146]
# 100%|██████████| 13/13 [00:01<00:00, 11.00it/s, avg_epoch_loss=0.0629, epoch=147]
# 100%|██████████| 13/13 [00:01<00:00, 10.96it/s, avg_epoch_loss=0.0782, epoch=148]
# 100%|██████████| 13/13 [00:01<00:00, 10.59it/s, avg_epoch_loss=0.0776, epoch=149]
# 100%|██████████| 13/13 [00:01<00:00, 10.62it/s, avg_epoch_loss=0.0705, epoch=150]
# 100%|██████████| 13/13 [00:01<00:00, 10.82it/s, avg_epoch_loss=0.043, epoch=151]
# 100%|██████████| 13/13 [00:01<00:00, 11.05it/s, avg_epoch_loss=0.0645, epoch=152]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.0545, epoch=153]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0555, epoch=154]
# 100%|██████████| 13/13 [00:01<00:00, 11.16it/s, avg_epoch_loss=0.0427, epoch=155]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0546, epoch=156]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0429, epoch=157]
# 100%|██████████| 13/13 [00:01<00:00, 11.18it/s, avg_epoch_loss=0.068, epoch=158]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.0449, epoch=159]
# 100%|██████████| 13/13 [00:01<00:00, 11.09it/s, avg_epoch_loss=0.0446, epoch=160]
# 100%|██████████| 13/13 [00:01<00:00, 11.16it/s, avg_epoch_loss=0.0448, epoch=161]
# 100%|██████████| 13/13 [00:01<00:00, 11.07it/s, avg_epoch_loss=0.0481, epoch=162]
# 100%|██████████| 13/13 [00:01<00:00, 11.07it/s, avg_epoch_loss=0.0467, epoch=163]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0556, epoch=164]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0515, epoch=165]
# 100%|██████████| 13/13 [00:01<00:00, 11.07it/s, avg_epoch_loss=0.0413, epoch=166]
# 100%|██████████| 13/13 [00:01<00:00, 11.24it/s, avg_epoch_loss=0.0685, epoch=167]
# 100%|██████████| 13/13 [00:01<00:00, 11.07it/s, avg_epoch_loss=0.0372, epoch=168]
# 100%|██████████| 13/13 [00:01<00:00, 11.15it/s, avg_epoch_loss=0.0617, epoch=169]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0561, epoch=170]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0599, epoch=171]
# 100%|██████████| 13/13 [00:01<00:00, 11.18it/s, avg_epoch_loss=0.0431, epoch=172]
# 100%|██████████| 13/13 [00:01<00:00, 11.18it/s, avg_epoch_loss=0.0561, epoch=173]
# 100%|██████████| 13/13 [00:01<00:00, 11.14it/s, avg_epoch_loss=0.0433, epoch=174]
# 100%|██████████| 13/13 [00:01<00:00, 11.07it/s, avg_epoch_loss=0.0476, epoch=175]
# 100%|██████████| 13/13 [00:01<00:00, 11.05it/s, avg_epoch_loss=0.039, epoch=176]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0484, epoch=177]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0494, epoch=178]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.053, epoch=179]
# 100%|██████████| 13/13 [00:01<00:00, 11.16it/s, avg_epoch_loss=0.0578, epoch=180]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0597, epoch=181]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.0358, epoch=182]
# 100%|██████████| 13/13 [00:01<00:00, 11.17it/s, avg_epoch_loss=0.04, epoch=183]
# 100%|██████████| 13/13 [00:01<00:00, 11.19it/s, avg_epoch_loss=0.0508, epoch=184]
# 100%|██████████| 13/13 [00:01<00:00, 11.07it/s, avg_epoch_loss=0.0392, epoch=185]
# 100%|██████████| 13/13 [00:01<00:00, 10.94it/s, avg_epoch_loss=0.0489, epoch=186]
# 100%|██████████| 13/13 [00:01<00:00, 10.97it/s, avg_epoch_loss=0.0605, epoch=187]
# 100%|██████████| 13/13 [00:01<00:00, 10.83it/s, avg_epoch_loss=0.0549, epoch=188]
# 100%|██████████| 13/13 [00:01<00:00, 10.74it/s, avg_epoch_loss=0.0421, epoch=189]
# 100%|██████████| 13/13 [00:01<00:00, 10.84it/s, avg_epoch_loss=0.0393, epoch=190]
# 100%|██████████| 13/13 [00:01<00:00, 10.89it/s, avg_epoch_loss=0.0493, epoch=191]
# 100%|██████████| 13/13 [00:01<00:00, 10.84it/s, avg_epoch_loss=0.0413, epoch=192]
# 100%|██████████| 13/13 [00:01<00:00, 10.63it/s, avg_epoch_loss=0.0457, epoch=193]
# 100%|██████████| 13/13 [00:01<00:00, 10.99it/s, avg_epoch_loss=0.0507, epoch=194]
# 100%|██████████| 13/13 [00:01<00:00, 10.87it/s, avg_epoch_loss=0.0535, epoch=195]
# 100%|██████████| 13/13 [00:01<00:00, 10.75it/s, avg_epoch_loss=0.0489, epoch=196]
# 100%|██████████| 13/13 [00:01<00:00, 11.09it/s, avg_epoch_loss=0.0504, epoch=197]
# 100%|██████████| 13/13 [00:01<00:00, 11.08it/s, avg_epoch_loss=0.0405, epoch=198]
# 100%|██████████| 13/13 [00:01<00:00, 10.94it/s, avg_epoch_loss=0.0454, epoch=199]

# %% [markdown]
# ## Imputation and evaluation

# %%
# generate the 100 imputed values for each miss
gen_iters = 100

res_imputed = []
for i in range(gen_iters):
    imputed_values = impute(CSDI, cust_df_test, length_of_sequence = length_of_seq, num_of_timestamps = 500, use_rolling_window = False )
    imputed_values.columns = df_train.segment.unique()
    imputed_values['date'] = df_train.timestamp.sort_values().unique()
    imp_transf = transform_format(imputed_values, imputed_values.columns[:-1])
    imp_transf.timestamp = imp_transf.timestamp.values.astype(int)
    sc_transf = sc_train.inverse_transform(imp_transf).sort_values(['timestamp', 'segment']).reset_index(drop = True)
    res_imputed.append(sc_transf[sc_transf.index.isin(missing_values)].sort_index())
    print(str(i+1), '/', str(gen_iters))
# Out:
# 1 / 100
# 2 / 100
# 3 / 100
# 4 / 100
# 5 / 100
# 6 / 100
# 7 / 100
# 8 / 100
# 9 / 100
# 10 / 100
# 11 / 100
# 12 / 100
# 13 / 100
# 14 / 100
# 15 / 100
# 16 / 100
# 17 / 100
# 18 / 100
# 19 / 100
# 20 / 100
# 21 / 100
# 22 / 100
# 23 / 100
# 24 / 100
# 25 / 100
# 26 / 100
# 27 / 100
# 28 / 100
# 29 / 100
# 30 / 100
# 31 / 100
# 32 / 100
# 33 / 100
# 34 / 100
# 35 / 100
# 36 / 100
# 37 / 100
# 38 / 100
# 39 / 100
# 40 / 100
# 41 / 100
# 42 / 100
# 43 / 100
# 44 / 100
# 45 / 100
# 46 / 100
# 47 / 100
# 48 / 100
# 49 / 100
# 50 / 100
# 51 / 100
# 52 / 100
# 53 / 100
# 54 / 100
# 55 / 100
# 56 / 100
# 57 / 100
# 58 / 100
# 59 / 100
# 60 / 100
# 61 / 100
# 62 / 100
# 63 / 100
# 64 / 100
# 65 / 100
# 66 / 100
# 67 / 100
# 68 / 100
# 69 / 100
# 70 / 100
# 71 / 100
# 72 / 100
# 73 / 100
# 74 / 100
# 75 / 100
# 76 / 100
# 77 / 100
# 78 / 100
# 79 / 100
# 80 / 100
# 81 / 100
# 82 / 100
# 83 / 100
# 84 / 100
# 85 / 100
# 86 / 100
# 87 / 100
# 88 / 100
# 89 / 100
# 90 / 100
# 91 / 100
# 92 / 100
# 93 / 100
# 94 / 100
# 95 / 100
# 96 / 100
# 97 / 100
# 98 / 100
# 99 / 100
# 100 / 100

# %%
# plot the imputed intervals
plot_intervals(df_train_only_missed, res_imputed, df_train_only_missed.segment.unique())

# %%
# compute quality metrics report
quality_metrics_report(res_imputed, df_train_only_missed, df_train_only_missed.segment.unique())
# Out:
#           RMSE       MAE       RSE       RAE       MAPE       NLPD    nRMSEp  \
# LULL  0.194794  0.137146  0.854291  0.781298   7.943386   5.015408  3.768814
# OT    4.177224  3.268503  0.905909  0.791603  13.662525   9.293352  4.065687
# LUFL  0.600961  0.441697  1.091227  0.933214  14.071078  10.487758  4.810033
# MULL  0.702199  0.551455  0.904836  0.925922  34.962103   7.910214  4.190598
# HUFL  1.687693  1.405463  0.675975  0.676869  15.727859   5.930671  3.326133
# MUFL  1.498511  1.115507  0.764261  0.770595  25.578469    4.44999  2.908698
# HULL  0.938108  0.741324  0.828236   0.79401  17.081971   4.030972  2.943265
#
#        PICP_68   PICP_95
# LULL  0.272727  0.527273
# OT    0.214286  0.428571
# LUFL  0.265306  0.469388
# MULL  0.222222  0.361111
# HUFL  0.244898  0.489796
# MUFL  0.323529  0.617647
# HULL  0.263158  0.473684

# %%
# plot one trajectory of imputed values 
plot_predictions(df_train_only_missed, 
                       res_imputed[0], 
                       df_train_only_missed[['timestamp','segment']], 
                       df_train_only_missed.segment.unique())
